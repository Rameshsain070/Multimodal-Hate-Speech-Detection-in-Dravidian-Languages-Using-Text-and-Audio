# %%
import os
import time
from huggingface_hub import notebook_login

# 1. Uninstall conflicts
print("🧹 Cleaning up environment...")
os.system("pip uninstall -y torch torchvision torchaudio libcugraph-cu12 pylibcugraph-cu12 pylibraft-cu12 rmm-cu12")

# 2. Install PyTorch 2.6.0 (Required to fix CVE-2025-32434)
# We use CUDA 12.1 wheels which are very stable on Kaggle
print("⬇️ Installing PyTorch 2.6.0 (Secure Version)...")
os.system("pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu121")

# 3. Install Training Libraries
print("⬇️ Installing Transformers & Tools...")
os.system("pip install -q transformers datasets evaluate accelerate scikit-learn huggingface_hub librosa soundfile")
# 4. Import & Login
print("\n" + "="*30)
print("   PLEASE PROVIDE YOUR HUGGING FACE TOKEN")
print("="*30)
token = "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"
from huggingface_hub import login

# Replace 'YOUR_HF_TOKEN' with your actual Hugging Face access token
login(token="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")

# This will create a popup. Paste your 'hf_...' WRITE token here.
# notebook_login(token="")

print("✅ Setup Complete. Ready for Cell 2.")
# Out:
# 🧹 Cleaning up environment...
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Found existing installation: libcugraph-cu12 25.6.0
# Uninstalling libcugraph-cu12-25.6.0:
#   Successfully uninstalled libcugraph-cu12-25.6.0
# Found existing installation: pylibcugraph-cu12 25.6.0
# Uninstalling pylibcugraph-cu12-25.6.0:
#   Successfully uninstalled pylibcugraph-cu12-25.6.0
# Found existing installation: pylibraft-cu12 25.2.0
# Uninstalling pylibraft-cu12-25.2.0:
#   Successfully uninstalled pylibraft-cu12-25.2.0
# Found existing installation: rmm-cu12 25.2.0
# Uninstalling rmm-cu12-25.2.0:
#   Successfully uninstalled rmm-cu12-25.2.0
# ⬇️ Installing PyTorch 2.6.0 (Secure Version)...
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch==2.6.0 (from versions: 2.1.0+cu121, 2.1.1+cu121, 2.1.2+cu121, 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.6.0
# ⬇️ Installing Transformers & Tools...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 128.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 112.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml-cu12 25.2.1 requires pylibraft-cu12==25.2.*, which is not installed.
# cuml-cu12 25.2.1 requires rmm-cu12==25.2.*, which is not installed.
# pylibcudf-cu12 25.2.2 requires rmm-cu12==25.2.*, which is not installed.
# cudf-cu12 25.2.2 requires rmm-cu12==25.2.*, which is not installed.
# cuvs-cu12 25.2.1 requires pylibraft-cu12==25.2.*, which is not installed.
# easyocr 1.7.2 requires torchvision>=0.5, which is not installed.
# fastai 2.8.5 requires torchvision>=0.11, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# timm 1.0.19 requires torchvision, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# ==============================
#    PLEASE PROVIDE YOUR HUGGING FACE TOKEN
# ==============================
# ✅ Setup Complete. Ready for Cell 2.

# %%
HF_USERNAME = "ramesh070"
HF_TOKEN = "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"
print("set user")
# Out:
# set user

# %%
# ==========================================
# CELL 2: CONFIGURATION (MALAYALAM) - BINARY
# ==========================================
import os
import pandas as pd
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split

# --- Safe torch import ---
try:
    import torch
    _TORCH_AVAILABLE = True
except Exception:
    torch = None
    _TORCH_AVAILABLE = False

class Config:
    # 1. Project Settings
    LANG = "Malayalam"
    LANG_CODE = "ml" 
    NUM_CLASSES = 2  
    LABEL_MAP = {'N': 0, 'C': 1, 'G': 1, 'P': 1, 'R': 1}  

    # 2. Paths
    BASE_PATH = "/kaggle/input/hate-speech-detection-in-dravidian-languages"
    INNER_FOLDER = "Hate Speech Detection in Dravidian languages"
    DATASET_ROOT = os.path.join(BASE_PATH, INNER_FOLDER)
    
    TEXT_TRAIN_PATH = f"{DATASET_ROOT}/train/{LANG.lower()}/text/ML-AT-train.csv"
    TEXT_TEST_PATH = f"{DATASET_ROOT}/test/{LANG.lower()}/text/ML-AT-test.csv"

    # 3. Model Settings
    DEVICE = "cuda" if (_TORCH_AVAILABLE and torch.cuda.is_available()) else "cpu"
    MODELS_TO_TRAIN = {
        "indicbert": "ai4bharat/IndicBERTv2-MLM-only",
        "xlm-r": "FacebookAI/xlm-roberta-base",
        "mbert": "google-bert/bert-base-multilingual-cased"
    }

    # --- SAFETENSORS HELPER ---
    SAFETENSORS_MODELS = {
       "ai4bharat/IndicBERTv2-MLM-only": True
    }

    @classmethod
    def get_model_load_kwargs(cls, model_name: str):
        return {"use_safetensors": True} if cls.SAFETENSORS_MODELS.get(model_name, False) else {}

print(f"✅ Configured for {Config.LANG} on {Config.DEVICE}")
print(f"   Train CSV: {Config.TEXT_TRAIN_PATH}")

# 4. Load and Prepare Data
try:
    # Load raw data
    train_df = pd.read_csv(Config.TEXT_TRAIN_PATH)
    
    # Rename, clean, and map labels
    train_df = train_df[['Transcript', 'Class Label Short']].rename(columns={
        'Transcript': 'text',
        'Class Label Short': 'label_str'
    })
    train_df['text'] = train_df['text'].fillna("").astype(str)
    train_df['label'] = train_df['label_str'].map(Config.LABEL_MAP)
    
    # Drop rows with invalid labels
    train_df = train_df.dropna(subset=['label'])
    train_df['label'] = train_df['label'].astype(int)

    # --- MODIFIED SPLIT LOGIC (80% Train, 10% Val, 10% Test) ---
    
    # Step 1: Split into 80% Train and 20% Temp (Val + Test)
    train_split, temp_split = train_test_split(
        train_df, test_size=0.2, random_state=42, stratify=train_df['label']
    )
    
    # Step 2: Split the 20% Temp into equal halves (10% Val, 10% Test)
    eval_split, test_split = train_test_split(
        temp_split, test_size=0.5, random_state=42, stratify=temp_split['label']
    )
    
    # Convert to Hugging Face Dataset objects
    train_ds = Dataset.from_pandas(train_split)
    eval_ds = Dataset.from_pandas(eval_split)
    test_ds = Dataset.from_pandas(test_split) # Available for final inference if needed
    
    print("\n✅ Data Loaded and Split (80/10/10):")
    print(f"   Training Examples:   {len(train_ds)}")
    print(f"   Validation Examples: {len(eval_ds)}")
    print(f"   Test Examples:       {len(test_ds)}")

except Exception as e:
    print(f"❌ ERROR loading data: {e}")
# Out:
# ✅ Configured for Malayalam on cuda
#    Train CSV: /kaggle/input/hate-speech-detection-in-dravidian-languages/Hate Speech Detection in Dravidian languages/train/malayalam/text/ML-AT-train.csv
#
# ✅ Data Loaded and Split (80/10/10):
#    Training Examples:   706
#    Validation Examples: 88
#    Test Examples:       89

# %%
# ==========================================
# CELL 3: DEEP CLEAN & TRAIN - BINARY CLASSIFICATION
# ==========================================
# !pip install -q evaluate

import gc
import os
import shutil
import numpy as np
import evaluate
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)

# --- STEP 1: AGGRESSIVE DISK CLEANUP ---
print("🧹 STARTING DISK CLEANUP...")

for item in os.listdir("./"):
    if os.path.isdir(item) and ("hatespeech" in item or "checkpoint" in item or "runs" in item):
        print(f"   - Deleting folder: {item}")
        shutil.rmtree(item, ignore_errors=True)

print("✅ Disk Cleaned. Starting Training Loop.")

# --- STEP 2: SETUP METRICS ---
def compute_metrics(eval_pred):
    f1_metric = evaluate.load("f1")
    acc_metric = evaluate.load("accuracy")
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    f1 = f1_metric.compute(predictions=predictions, references=labels, average="binary")["f1"]
    acc = acc_metric.compute(predictions=predictions, references=labels)["accuracy"]
    return {"accuracy": acc, "f1": f1}

# --- STEP 3: TRAINING LOOP ---
for name, model_id in Config.MODELS_TO_TRAIN.items():
    
    print("\n" + "="*50)
    print(f"🔵 PROCESSING: {name} ({model_id})")
    print("="*50)
    
    # A. Load Model
    try:
        tokenizer = AutoTokenizer.from_pretrained(model_id)
        
        load_kwargs = {}
        if hasattr(Config, "get_model_load_kwargs"):
            try:
                load_kwargs = Config.get_model_load_kwargs(model_id) or {}
            except Exception:
                load_kwargs = {}

        model = AutoModelForSequenceClassification.from_pretrained(
            model_id, 
            num_labels=Config.NUM_CLASSES,
            **load_kwargs
        ).to(Config.DEVICE)
    except Exception as e:
        print(f"   ⚠️ FAILED TO LOAD MODEL: {e}")
        continue

    # B. Tokenize
    def tokenize_function(examples):
        return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=128)

    tokenized_train_ds = train_ds.map(tokenize_function, batched=True)
    tokenized_eval_ds = eval_ds.map(tokenize_function, batched=True)

    # C. Training Arguments
    hub_model_id = f"{HF_USERNAME}/{name}-hatespeechdetection-{Config.LANG.lower()}"
    output_dir = f"./{name}-hatespeechdetection-{Config.LANG.lower()}"

    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=20,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        learning_rate=2e-5,
        weight_decay=0.01,
        save_strategy="epoch",
        eval_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="accuracy",
        overwrite_output_dir=True,
        save_total_limit=1,
        logging_strategy="epoch",
        push_to_hub=True,
        hub_model_id=hub_model_id,
        hub_token=HF_TOKEN,
        report_to="none"
    )

# D. Train
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_train_ds,
        eval_dataset=tokenized_eval_ds,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics,
        # DELETE OR COMMENT OUT THE LINE BELOW TO FORCE 20 EPOCHS
        # callbacks=[EarlyStoppingCallback(early_stopping_patience=3)] 
    )
    print(f"   Starting training...")
    trainer.train()

    # E. Push Final Model
    print(f"   Pushing model to Hub...")
    trainer.push_to_hub()
    
    # F. AGGRESSIVE CLEANUP AFTER UPLOAD
    print(f"   ✅ Finished {name}. Deleting local files to free space for next model.")
    del model, trainer, tokenizer
    gc.collect()
    if torch is not None:
        torch.cuda.empty_cache()
    
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir, ignore_errors=True)

print("\n" + "="*50)
print("✅ ALL TEXT MODELS TRAINED AND UPLOADED.")
print("="*50)
# Out:
# 2025-12-03 05:45:13.205108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764740713.594670      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764740713.727505      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 🧹 STARTING DISK CLEANUP...
# ✅ Disk Cleaned. Starting Training Loop.
#
# ==================================================
# 🔵 PROCESSING: indicbert (ai4bharat/IndicBERTv2-MLM-only)
# ==================================================
# tokenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/IndicBERTv2-MLM-only and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# /tmp/ipykernel_47/3059088902.py:97: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#    Starting training...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 07:58, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.600400</td>
#       <td>0.305305</td>
#       <td>0.954545</td>
#       <td>0.957447</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220400</td>
#       <td>0.077805</td>
#       <td>0.977273</td>
#       <td>0.979592</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.081300</td>
#       <td>0.075013</td>
#       <td>0.988636</td>
#       <td>0.989691</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025000</td>
#       <td>0.085003</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.004000</td>
#       <td>0.106280</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.001600</td>
#       <td>0.113542</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001700</td>
#       <td>0.125467</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001500</td>
#       <td>0.125190</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000600</td>
#       <td>0.135809</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000500</td>
#       <td>0.139784</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000400</td>
#       <td>0.142035</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000400</td>
#       <td>0.143904</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000300</td>
#       <td>0.146683</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000300</td>
#       <td>0.148206</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000500</td>
#       <td>0.150129</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000300</td>
#       <td>0.151867</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000300</td>
#       <td>0.152908</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000300</td>
#       <td>0.153645</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000300</td>
#       <td>0.154087</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000300</td>
#       <td>0.154245</td>
#       <td>0.977273</td>
#       <td>0.979167</td>
#     </tr>
#   </tbody>
# </table><p>
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    Pushing model to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    ✅ Finished indicbert. Deleting local files to free space for next model.
#
# ==================================================
# 🔵 PROCESSING: xlm-r (FacebookAI/xlm-roberta-base)
# ==================================================
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at FacebookAI/xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# /tmp/ipykernel_47/3059088902.py:97: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#    Starting training...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 08:07, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.600100</td>
#       <td>0.499269</td>
#       <td>0.795455</td>
#       <td>0.769231</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.383800</td>
#       <td>0.114177</td>
#       <td>0.965909</td>
#       <td>0.968421</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.282800</td>
#       <td>0.107257</td>
#       <td>0.965909</td>
#       <td>0.968421</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.148600</td>
#       <td>0.122277</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.107000</td>
#       <td>0.133035</td>
#       <td>0.954545</td>
#       <td>0.957447</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.101500</td>
#       <td>0.176109</td>
#       <td>0.965909</td>
#       <td>0.968421</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.047600</td>
#       <td>0.133974</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.040500</td>
#       <td>0.200347</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.027600</td>
#       <td>0.155498</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.020600</td>
#       <td>0.212922</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.001300</td>
#       <td>0.193852</td>
#       <td>0.965909</td>
#       <td>0.968421</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.003700</td>
#       <td>0.188815</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000300</td>
#       <td>0.185127</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.018100</td>
#       <td>0.283829</td>
#       <td>0.965909</td>
#       <td>0.968421</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.001100</td>
#       <td>0.193567</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000400</td>
#       <td>0.208443</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000400</td>
#       <td>0.208088</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000200</td>
#       <td>0.206246</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000200</td>
#       <td>0.207178</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000200</td>
#       <td>0.206948</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    Pushing model to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    ✅ Finished xlm-r. Deleting local files to free space for next model.
#
# ==================================================
# 🔵 PROCESSING: mbert (google-bert/bert-base-multilingual-cased)
# ==================================================
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google-bert/bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# /tmp/ipykernel_47/3059088902.py:97: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#    Starting training...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 06:07, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.574900</td>
#       <td>0.432511</td>
#       <td>0.795455</td>
#       <td>0.780488</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.283600</td>
#       <td>0.214229</td>
#       <td>0.909091</td>
#       <td>0.911111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119100</td>
#       <td>0.216146</td>
#       <td>0.943182</td>
#       <td>0.947368</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.051200</td>
#       <td>0.501708</td>
#       <td>0.886364</td>
#       <td>0.886364</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.043400</td>
#       <td>0.436566</td>
#       <td>0.897727</td>
#       <td>0.898876</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.041700</td>
#       <td>0.311697</td>
#       <td>0.909091</td>
#       <td>0.914894</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.009600</td>
#       <td>0.815766</td>
#       <td>0.863636</td>
#       <td>0.860465</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.016700</td>
#       <td>0.599062</td>
#       <td>0.897727</td>
#       <td>0.898876</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.022200</td>
#       <td>0.511899</td>
#       <td>0.909091</td>
#       <td>0.911111</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000600</td>
#       <td>0.372354</td>
#       <td>0.931818</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.006200</td>
#       <td>0.344059</td>
#       <td>0.954545</td>
#       <td>0.959184</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.003400</td>
#       <td>0.346568</td>
#       <td>0.931818</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000400</td>
#       <td>0.406144</td>
#       <td>0.943182</td>
#       <td>0.947368</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.003700</td>
#       <td>0.389754</td>
#       <td>0.943182</td>
#       <td>0.947368</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000300</td>
#       <td>0.471237</td>
#       <td>0.931818</td>
#       <td>0.936170</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000300</td>
#       <td>0.401689</td>
#       <td>0.931818</td>
#       <td>0.938776</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000300</td>
#       <td>0.405031</td>
#       <td>0.931818</td>
#       <td>0.938776</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000300</td>
#       <td>0.440106</td>
#       <td>0.943182</td>
#       <td>0.947368</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000200</td>
#       <td>0.442497</td>
#       <td>0.931818</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000200</td>
#       <td>0.442852</td>
#       <td>0.931818</td>
#       <td>0.937500</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    Pushing model to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    ✅ Finished mbert. Deleting local files to free space for next model.
#
# ==================================================
# ✅ ALL TEXT MODELS TRAINED AND UPLOADED.
# ==================================================

# %% [markdown]
# **AUDIO**

# %%
# ==========================================
# CELL 1: FAST INSTALL (BYPASSING ERRORS)
# ==========================================
# We use --no-deps to stop pip from trying to downgrade scikit-learn
# We manually install the small helpers audiomentations needs
# !pip install audiomentations --no-deps
# !pip install numpy-minmax numpy-rms python-stretch

print("✅ Audiomentations installed without dependency errors!")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting audiomentations
#   Downloading audiomentations-0.43.1-py3-none-any.whl.metadata (11 kB)
# Downloading audiomentations-0.43.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: audiomentations
# Successfully installed audiomentations-0.43.1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting numpy-minmax
#   Downloading numpy_minmax-0.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting numpy-rms
#   Downloading numpy_rms-0.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting python-stretch
#   Downloading python_stretch-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from numpy-minmax) (2.0.0)
# Collecting numpy<3,>=2 (from numpy-minmax)
#   Downloading numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.0->numpy-minmax) (2.23)
# Downloading numpy_minmax-0.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading numpy_rms-0.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17 kB)
# Downloading python_stretch-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 4.2 MB/s eta 0:00:00
# Downloading numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 99.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: python-stretch, numpy, numpy-rms, numpy-minmax
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml-cu12 25.2.1 requires pylibraft-cu12==25.2.*, which is not installed.
# cuml-cu12 25.2.1 requires rmm-cu12==25.2.*, which is not installed.
# cudf-cu12 25.2.2 requires rmm-cu12==25.2.*, which is not installed.
# cuvs-cu12 25.2.1 requires pylibraft-cu12==25.2.*, which is not installed.
# ucxx-cu12 0.42.0 requires rmm-cu12==25.2.*, which is not installed.
# easyocr 1.7.2 requires torchvision>=0.5, which is not installed.
# fastai 2.8.5 requires torchvision>=0.11, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# nx-cugraph-cu12 25.6.0 requires pylibcugraph-cu12==25.6.*, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.5 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-2.3.5 numpy-minmax-0.5.0 numpy-rms-0.6.0 python-stretch-0.3.1
# ✅ Audiomentations installed without dependency errors!

# %% [markdown]
# Wav2Vec2

# %%
# ==============================================================================
# CELL: MULTI-MODEL AUDIO TRAINING (80/10/10 SPLIT)
# ==============================================================================

import os
import gc
import shutil
import numpy as np
import pandas as pd
import torch
import librosa
import evaluate
from torch import nn
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from datasets import Dataset
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift
from transformers import (
    AutoModelForAudioClassification,
    AutoFeatureExtractor,
    TrainingArguments,
    Trainer,
    default_data_collator
)
from huggingface_hub import login

# ==========================================
# 1. CONFIGURATION
# ==========================================
class Config:
    # Paths
    AUDIO_DIR = "/kaggle/input/hate-speech-detection-in-dravidian-languages/Hate Speech Detection in Dravidian languages/train/malayalam/audio"
    CSV_PATH = "/kaggle/input/hate-speech-detection-in-dravidian-languages/Hate Speech Detection in Dravidian languages/train/malayalam/text/ML-AT-train.csv"
    
    # Models to Train
    # Dictionary format: { "Short_Name": "HuggingFace_Model_ID" }
    MODELS_TO_TRAIN = {
        "wav2vec2": "facebook/wav2vec2-large-xlsr-53",
        "wavlm": "microsoft/wavlm-base",
        "mms": "facebook/mms-300m" # 3rd Best: Excellent for Dravidian languages
    }
    
    NUM_CLASSES = 2  
    LABEL_MAP = {'N': 0, 'C': 1, 'G': 1, 'P': 1, 'R': 1} 
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    
    # Params (Same for all models)
    MAX_DURATION = 5.0
    SAMPLING_RATE = 16000
    BATCH_SIZE = 4
    GRAD_ACCUMULATION = 4
    LEARNING_RATE = 3e-5
    EPOCHS = 20 # Restored to 20 as requested

    # HF Info
    HF_USERNAME = "ramesh070"
    HF_TOKEN = "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" 

# Login to HF
login(token=Config.HF_TOKEN)

# ==========================================
# 2. DATA PREPARATION (COMMON SPLIT)
# ==========================================
print("🔵 1. Loading and Splitting Data (Common Split)...")

if not os.path.exists(Config.AUDIO_DIR):
    raise FileNotFoundError(f"❌ Audio Directory not found at: {Config.AUDIO_DIR}")

try:
    df = pd.read_csv(Config.CSV_PATH)
    df = df.rename(columns={'Transcript': 'text', 'Class Label Short': 'label_str'})
except Exception as e:
    print(f"❌ Error loading CSV: {e}")
    raise e

# Map Labels & Paths
df['label'] = df['label_str'].map(Config.LABEL_MAP)

def get_audio_path(filename):
    filename = str(filename).strip()
    if not filename.lower().endswith('.wav'):
        filename += '.wav'
    return os.path.join(Config.AUDIO_DIR, filename)

df['audio_path'] = df['File Name'].apply(get_audio_path)
df = df[df['audio_path'].apply(os.path.exists)]
df = df.dropna(subset=['label'])
df['label'] = df['label'].astype(int)

# --- STATIC SPLIT LOGIC (80/10/10) ---
# We split the DATAFRAMES first so every model uses the exact same rows
train_df, temp_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)
eval_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['label'], random_state=42)

print(f"✅ Data Splits Created (Will be reused for all models):")
print(f"   Train: {len(train_df)} | Val: {len(eval_df)} | Test: {len(test_df)}")

# Calculate Weights (on Train set only)
class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_df['label']),
    y=train_df['label']
)
class_weights = torch.tensor(class_weights_arr, dtype=torch.float).to(Config.DEVICE)
print(f"⚖️ Class Weights: {class_weights.cpu().numpy()}")

# ==========================================
# 3. TRAINING LOOP (ALL 3 MODELS)
# ==========================================

# Define Helper Functions
augmentations = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
])

class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

def compute_metrics(eval_pred):
    f1_metric = evaluate.load("f1")
    acc_metric = evaluate.load("accuracy")
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    f1 = f1_metric.compute(predictions=preds, references=labels, average="binary")["f1"]
    acc = acc_metric.compute(predictions=preds, references=labels)["accuracy"]
    return {"accuracy": acc, "f1": f1}

# --- START LOOP ---
for short_name, model_id in Config.MODELS_TO_TRAIN.items():
    print("\n" + "="*50)
    print(f"🚀 STARTING PIPELINE FOR: {short_name} ({model_id})")
    print("="*50)
    
    # A. Feature Extractor
    # We load a fresh extractor for each model because they might normalize differently
    feature_extractor = AutoFeatureExtractor.from_pretrained(model_id)

    # B. Dataset Creation (Specific to this model's extractor)
    def preprocess_audio(batch, split="train"):
        audio_arrays = []
        for path in batch["audio_path"]:
            try:
                speech, sr = librosa.load(path, sr=Config.SAMPLING_RATE)
                # Augment ONLY training data
                if split == "train":
                    speech = augmentations(samples=speech, sample_rate=Config.SAMPLING_RATE)
                audio_arrays.append(speech)
            except:
                audio_arrays.append(np.zeros(Config.SAMPLING_RATE))
                
        inputs = feature_extractor(
            audio_arrays, 
            sampling_rate=Config.SAMPLING_RATE, 
            max_length=int(Config.SAMPLING_RATE * Config.MAX_DURATION), 
            truncation=True, 
            padding="max_length"
        )
        return {"input_values": inputs.input_values, "label": batch["label"]}

    # Create Datasets from the common dataframes
    train_ds = Dataset.from_pandas(train_df).map(lambda x: preprocess_audio(x, "train"), batched=True, batch_size=Config.BATCH_SIZE)
    eval_ds = Dataset.from_pandas(eval_df).map(lambda x: preprocess_audio(x, "test"), batched=True, batch_size=Config.BATCH_SIZE)
    test_ds = Dataset.from_pandas(test_df).map(lambda x: preprocess_audio(x, "test"), batched=True, batch_size=Config.BATCH_SIZE)

    # C. Load Model
    try:
        model = AutoModelForAudioClassification.from_pretrained(
            model_id,
            num_labels=Config.NUM_CLASSES,
            ignore_mismatched_sizes=True,
            attention_dropout=0.1,
            hidden_dropout=0.1,
            feat_proj_dropout=0.05
        ).to(Config.DEVICE)
        
        # FREEZE BACKBONE (Prevents Overfitting on small data)
        model.freeze_feature_encoder()
        
    except Exception as e:
        print(f"❌ Failed to load {short_name}: {e}")
        continue

    # D. Training Config
    repo_name = f"{short_name}-malayalam-binary"
    output_dir = repo_name # Local folder
    
    if os.path.exists(output_dir): shutil.rmtree(output_dir)

    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=Config.EPOCHS,
        per_device_train_batch_size=Config.BATCH_SIZE,
        per_device_eval_batch_size=Config.BATCH_SIZE,
        gradient_accumulation_steps=Config.GRAD_ACCUMULATION,
        learning_rate=Config.LEARNING_RATE,
        weight_decay=0.01,
        warmup_ratio=0.1,
        logging_strategy="epoch",
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="accuracy",
        save_total_limit=1,
        fp16=True if Config.DEVICE == "cuda" else False,
        report_to="none",
        
        # HF Push
        push_to_hub=True,
        hub_model_id=f"{Config.HF_USERNAME}/{repo_name}",
        hub_token=Config.HF_TOKEN
    )

    # E. Initialize Trainer
    trainer = WeightedTrainer(
        model=model,
        args=training_args,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        processing_class=feature_extractor,
        data_collator=default_data_collator,
        compute_metrics=compute_metrics,
    )

    # F. Train & Save
    print(f"   🏃‍♂️ Training {short_name}...")
    trainer.train()
    
    # Save locally to ensure all config files are generated
    trainer.save_model(output_dir)
    
    # G. Evaluate on Test Set
    print(f"   📊 Evaluating {short_name} on Test Set...")
    test_results = trainer.predict(test_ds)
    print(f"   🏆 {short_name} Results:", test_results.metrics)

    # H. Push to Hub & Cleanup
    print(f"   ☁️ Pushing {short_name} to Hub...")
    trainer.push_to_hub()
    
    print(f"   🧹 Cleaning up {short_name}...")
    del model, trainer, train_ds, eval_ds, test_ds
    gc.collect()
    torch.cuda.empty_cache()
    if os.path.exists(output_dir): shutil.rmtree(output_dir)

print("\n✅ ALL MODELS TRAINED SUCCESSFULLY!")
# Out:
# 🔵 1. Loading and Splitting Data (Common Split)...
# ✅ Data Splits Created (Will be reused for all models):
#    Train: 706 | Val: 88 | Test: 89
# ⚖️ Class Weights: [1.0861539 0.9265092]
#
# ==================================================
# 🚀 STARTING PIPELINE FOR: wav2vec2 (facebook/wav2vec2-large-xlsr-53)
# ==================================================
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# Map:   0%|          | 0/89 [00:00<?, ? examples/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#    🏃‍♂️ Training wav2vec2...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 44:00, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.671000</td>
#       <td>0.693024</td>
#       <td>0.545455</td>
#       <td>0.705882</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.670100</td>
#       <td>0.692839</td>
#       <td>0.545455</td>
#       <td>0.705882</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.666300</td>
#       <td>0.692204</td>
#       <td>0.511364</td>
#       <td>0.188679</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.639600</td>
#       <td>0.618542</td>
#       <td>0.943182</td>
#       <td>0.946237</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.502500</td>
#       <td>0.388289</td>
#       <td>0.920455</td>
#       <td>0.927835</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.340000</td>
#       <td>0.224424</td>
#       <td>0.931818</td>
#       <td>0.938776</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.213500</td>
#       <td>0.151366</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.155300</td>
#       <td>0.088451</td>
#       <td>0.988636</td>
#       <td>0.989474</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.127100</td>
#       <td>0.059898</td>
#       <td>0.988636</td>
#       <td>0.989474</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.102100</td>
#       <td>0.151398</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.104700</td>
#       <td>0.088222</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.064900</td>
#       <td>0.143627</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.097600</td>
#       <td>0.144219</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.053500</td>
#       <td>0.169622</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.043100</td>
#       <td>0.088600</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.081700</td>
#       <td>0.196993</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.046300</td>
#       <td>0.202115</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.057300</td>
#       <td>0.120255</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.034600</td>
#       <td>0.103013</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.049300</td>
#       <td>0.122547</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    📊 Evaluating wav2vec2 on Test Set...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    🏆 wav2vec2 Results: {'test_loss': 0.13487786054611206, 'test_accuracy': 0.9550561797752809, 'test_f1': 0.9574468085106383, 'test_runtime': 9.1896, 'test_samples_per_second': 9.685, 'test_steps_per_second': 1.306}
#    ☁️ Pushing wav2vec2 to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
#    🧹 Cleaning up wav2vec2...
#
# ==================================================
# 🚀 STARTING PIPELINE FOR: wavlm (microsoft/wavlm-base)
# ==================================================
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# Map:   0%|          | 0/89 [00:00<?, ? examples/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Some weights of WavLMForSequenceClassification were not initialized from the model checkpoint at microsoft/wavlm-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
#    🏃‍♂️ Training wavlm...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 23:17, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.663100</td>
#       <td>0.653676</td>
#       <td>0.840909</td>
#       <td>0.847826</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.469900</td>
#       <td>0.267657</td>
#       <td>0.920455</td>
#       <td>0.924731</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.244100</td>
#       <td>0.237845</td>
#       <td>0.931818</td>
#       <td>0.933333</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.142400</td>
#       <td>0.172198</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.097000</td>
#       <td>0.157920</td>
#       <td>0.965909</td>
#       <td>0.969072</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.109700</td>
#       <td>0.166214</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.040000</td>
#       <td>0.184261</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.059100</td>
#       <td>0.204084</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.026200</td>
#       <td>0.226134</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.024900</td>
#       <td>0.322608</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.040100</td>
#       <td>0.176098</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.019900</td>
#       <td>0.189597</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.012000</td>
#       <td>0.200073</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.012800</td>
#       <td>0.217063</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.028900</td>
#       <td>0.227547</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000100</td>
#       <td>0.236703</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.019700</td>
#       <td>0.245410</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.008300</td>
#       <td>0.343241</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000200</td>
#       <td>0.332653</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.001800</td>
#       <td>0.279983</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    📊 Evaluating wavlm on Test Set...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    🏆 wavlm Results: {'test_loss': 0.23436565697193146, 'test_accuracy': 0.9662921348314607, 'test_f1': 0.967741935483871, 'test_runtime': 7.0514, 'test_samples_per_second': 12.622, 'test_steps_per_second': 1.702}
#    ☁️ Pushing wavlm to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
#    🧹 Cleaning up wavlm...
#
# ==================================================
# 🚀 STARTING PIPELINE FOR: mms (facebook/mms-300m)
# ==================================================
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Map:   0%|          | 0/706 [00:00<?, ? examples/s]
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# Map:   0%|          | 0/89 [00:00<?, ? examples/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/mms-300m and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#    🏃‍♂️ Training mms...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 44:17, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.665300</td>
#       <td>0.682048</td>
#       <td>0.795455</td>
#       <td>0.780488</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.576400</td>
#       <td>0.413385</td>
#       <td>0.920455</td>
#       <td>0.921348</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.384300</td>
#       <td>0.182484</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.228500</td>
#       <td>0.169482</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.164900</td>
#       <td>0.110799</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.139400</td>
#       <td>0.139026</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.114100</td>
#       <td>0.132936</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.079800</td>
#       <td>0.104350</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.074300</td>
#       <td>0.220091</td>
#       <td>0.943182</td>
#       <td>0.945055</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.084600</td>
#       <td>0.265675</td>
#       <td>0.920455</td>
#       <td>0.921348</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.070100</td>
#       <td>0.147028</td>
#       <td>0.965909</td>
#       <td>0.967742</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.082000</td>
#       <td>0.195601</td>
#       <td>0.954545</td>
#       <td>0.956522</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.014500</td>
#       <td>0.126540</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.019100</td>
#       <td>0.134549</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.035500</td>
#       <td>0.139359</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.038000</td>
#       <td>0.143188</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.043700</td>
#       <td>0.146670</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.037400</td>
#       <td>0.149428</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012500</td>
#       <td>0.151106</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.057500</td>
#       <td>0.151741</td>
#       <td>0.977273</td>
#       <td>0.978723</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#    📊 Evaluating mms on Test Set...
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#    🏆 mms Results: {'test_loss': 0.12135282903909683, 'test_accuracy': 0.9662921348314607, 'test_f1': 0.967741935483871, 'test_runtime': 9.0609, 'test_samples_per_second': 9.822, 'test_steps_per_second': 1.324}
#    ☁️ Pushing mms to Hub...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
#    🧹 Cleaning up mms...
#
# ✅ ALL MODELS TRAINED SUCCESSFULLY!

# %%
# === MEMORY-SAFE META BUILD & TRAIN CELL (use existing eval_df & test_df) ===
# Requirements: transformers, torch, librosa, numpy, pandas, sklearn, lightgbm, joblib, tqdm
# pip install transformers librosa lightgbm joblib tqdm

import os, gc, sys, time
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch, librosa
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    AutoFeatureExtractor,
    AutoModelForAudioClassification,
)
import lightgbm as lgb
import joblib
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score

# -------- CONFIG (tune these if needed) ----------------
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TEXT_BATCH_SIZE = 16          # batch size for text models (small text models OK)
AUDIO_BATCH_SIZE = 2          # very small to avoid OOM; set to 1 if still OOM
TARGET_SR = 16000
USE_DEVICE = DEVICE           # 'cuda' or 'cpu' (auto)
SAVE_PER_MODEL = False        # set True if you want per-model .npy saved

# -------- HF model repo paths (your best-epoch checkpoints) ----------
audio_model_paths = [
    "ramesh070/mms-malayalam-binary",
    "ramesh070/wavlm-malayalam-binary",
    "ramesh070/wav2vec2-malayalam-binary",
]

text_model_paths = [
    "ramesh070/mbert-hatespeechdetection-malayalam",
    "ramesh070/xlm-r-hatespeechdetection-malayalam",
    "ramesh070/indicbert-hatespeechdetection-malayalam",
]

# ---------------- helper utils --------------------------------
def softmax(x):
    e = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e / e.sum(axis=-1, keepdims=True)

def ensure_2class_probs(logits_or_probs):
    arr = np.asarray(logits_or_probs)
    if arr.ndim == 1:
        p1 = 1.0 / (1.0 + np.exp(-arr))
        p0 = 1.0 - p1
        return np.vstack([p0, p1]).T
    if arr.shape[1] == 2:
        s = arr.sum(axis=1)
        if not np.allclose(s, 1.0, atol=1e-3):
            return softmax(arr)
        return arr
    p = softmax(arr)
    if p.shape[1] >= 2:
        return p[:, :2]
    p1 = p.squeeze()
    p0 = 1.0 - p1
    return np.vstack([p0, p1]).T

def free_gpu():
    try:
        torch.cuda.empty_cache()
    except Exception:
        pass
    gc.collect()

# ---------------- text inference (one-model-at-a-time) -----------------------
def get_text_probs_from_model_streaming(model_name, texts, batch_size=TEXT_BATCH_SIZE, device=USE_DEVICE):
    """
    Load text model once, predict on texts in batches, then unload model.
    Returns (N,2) probabilities.
    Retries on CPU if OOM on GPU.
    """
    try_device = device
    for attempt in range(2):
        try:
            tok = AutoTokenizer.from_pretrained(model_name)
            model = AutoModelForSequenceClassification.from_pretrained(model_name)
            if try_device == "cuda" and torch.cuda.is_available():
                model.to("cuda")
            else:
                model.to("cpu")
            model.eval()

            probs_list = []
            with torch.no_grad():
                for i in range(0, len(texts), batch_size):
                    batch = texts[i:i+batch_size]
                    enc = tok(batch, truncation=True, padding=True, return_tensors="pt")
                    enc = {k: v.to(next(model.parameters()).device) for k, v in enc.items()}
                    out = model(**enc)
                    logits = out.logits.detach().cpu().numpy()
                    probs = ensure_2class_probs(logits)
                    probs_list.append(probs)

                    # free batch tensors
                    del enc, out, logits
                    free_gpu()

            # cleanup model
            model.to("cpu")
            del model, tok
            free_gpu()
            return np.vstack(probs_list)

        except RuntimeError as e:
            err = str(e)
            print(f"[text model {model_name}] RuntimeError: {err}")
            # if CUDA OOM, retry on CPU
            if 'out of memory' in err.lower() or try_device == "cuda":
                print(f"[text model {model_name}] retrying on CPU...")
                try_device = "cpu"
                free_gpu()
                continue
            else:
                raise e
    raise RuntimeError(f"Failed to run text model {model_name}")

# ---------------- audio inference (streaming, memory-safe) -------------------
def get_audio_probs_from_model_streaming(model_name, audio_paths, batch_size=AUDIO_BATCH_SIZE, target_sr=TARGET_SR, device=USE_DEVICE):
    """
    Memory-safe audio inference:
      - load model & feature extractor one at a time
      - stream audio files in tiny batches
      - if GPU OOM happens retry on CPU
    """
    try_device = device
    for attempt in range(2):
        try:
            feat = AutoFeatureExtractor.from_pretrained(model_name)
            model = AutoModelForAudioClassification.from_pretrained(model_name)
            if try_device == "cuda" and torch.cuda.is_available():
                model.to("cuda")
            else:
                model.to("cpu")
            model.eval()

            probs_list = []
            with torch.no_grad():
                for i in range(0, len(audio_paths), batch_size):
                    batch_paths = audio_paths[i:i+batch_size]
                    batch_wavs = []
                    for p in batch_paths:
                        try:
                            wav, sr = librosa.load(p, sr=target_sr)
                        except Exception:
                            # fallback 1s zeros if missing/corrupt
                            wav = np.zeros(int(target_sr * 1.0), dtype=np.float32)
                        batch_wavs.append(wav)

                    enc = feat(batch_wavs, sampling_rate=target_sr, return_tensors="pt", padding=True)
                    enc = {k: v.to(next(model.parameters()).device) for k, v in enc.items()}
                    out = model(**enc)
                    logits = out.logits.detach().cpu().numpy()
                    probs = ensure_2class_probs(logits)
                    probs_list.append(probs)

                    # free batch tensors
                    del enc, out, logits
                    free_gpu()

            # cleanup
            model.to("cpu")
            del model, feat
            free_gpu()
            return np.vstack(probs_list)

        except RuntimeError as e:
            err = str(e)
            print(f"[audio model {model_name}] RuntimeError: {err}")
            if 'out of memory' in err.lower() and try_device == "cuda":
                print(f"[audio model {model_name}] CUDA OOM - retrying on CPU (this will be slower).")
                try_device = "cpu"
                free_gpu()
                continue
            else:
                raise e
    raise RuntimeError(f"Failed to run audio model {model_name}")

def average_probs(list_of_probs):
    return np.mean(np.stack(list_of_probs, axis=0), axis=0)

# ------------------ ensure eval_df/test_df present -----------------------
if 'eval_df' not in globals() or 'test_df' not in globals():
    raise RuntimeError("eval_df/test_df not found in the notebook. Run the data-split cell first or load them into memory.")

# Basic sanity checks
for df_name in ('eval_df','test_df'):
    df = globals()[df_name]
    assert 'text' in df.columns and 'audio_path' in df.columns and 'label' in df.columns, \
        f"{df_name} must contain columns ['text','audio_path','label']"

print(f"DEVICE: {DEVICE} | TEXT_BATCH_SIZE: {TEXT_BATCH_SIZE} | AUDIO_BATCH_SIZE: {AUDIO_BATCH_SIZE}")
print(f"Eval size: {len(eval_df)} | Test size: {len(test_df)}")

# ---------------- produce per-model probs for eval ------------------------
print("Producing TEXT eval probs per model (one-at-a-time)...")
text_eval_probs_per_model = []
for m in text_model_paths:
    print("  ->", m)
    p = get_text_probs_from_model_streaming(m, eval_df['text'].tolist(), batch_size=TEXT_BATCH_SIZE, device=USE_DEVICE)
    text_eval_probs_per_model.append(p)
    if SAVE_PER_MODEL:
        np.save(f"text_eval_probs_{m.replace('/','_')}.npy", p)

text_eval_avg = average_probs(text_eval_probs_per_model)

print("Producing AUDIO eval probs per model (streaming, one-at-a-time)...")
audio_eval_probs_per_model = []
for m in audio_model_paths:
    print("  ->", m)
    p = get_audio_probs_from_model_streaming(m, eval_df['audio_path'].tolist(), batch_size=AUDIO_BATCH_SIZE, target_sr=TARGET_SR, device=USE_DEVICE)
    audio_eval_probs_per_model.append(p)
    if SAVE_PER_MODEL:
        np.save(f"audio_eval_probs_{m.replace('/','_')}.npy", p)

audio_eval_avg = average_probs(audio_eval_probs_per_model)

X_eval_meta = np.hstack([text_eval_avg, audio_eval_avg])  # shape (N_eval,4)
y_eval = eval_df['label'].astype(int).values

# ---------------- produce per-model probs for test ------------------------
print("Producing TEXT test probs per model...")
text_test_probs_per_model = []
for m in text_model_paths:
    print("  ->", m)
    p = get_text_probs_from_model_streaming(m, test_df['text'].tolist(), batch_size=TEXT_BATCH_SIZE, device=USE_DEVICE)
    text_test_probs_per_model.append(p)
    if SAVE_PER_MODEL:
        np.save(f"text_test_probs_{m.replace('/','_')}.npy", p)

text_test_avg = average_probs(text_test_probs_per_model)

print("Producing AUDIO test probs per model (streaming)...")
audio_test_probs_per_model = []
for m in audio_model_paths:
    print("  ->", m)
    p = get_audio_probs_from_model_streaming(m, test_df['audio_path'].tolist(), batch_size=AUDIO_BATCH_SIZE, target_sr=TARGET_SR, device=USE_DEVICE)
    audio_test_probs_per_model.append(p)
    if SAVE_PER_MODEL:
        np.save(f"audio_test_probs_{m.replace('/','_')}.npy", p)

audio_test_avg = average_probs(audio_test_probs_per_model)

X_test_meta = np.hstack([text_test_avg, audio_test_avg])  # (N_test,4)
y_test = test_df['label'].astype(int).values

# --------------- train LightGBM meta on eval (OOF) ------------------------
print("Training LightGBM meta on eval (OOF) features...")
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'num_leaves': 7,
    'max_depth': 3,
    'learning_rate': 0.05,
    'n_estimators': 150,
    'min_child_samples': 10,
    'verbosity': -1,
}
meta = lgb.LGBMClassifier(**params)
meta.fit(X_eval_meta, y_eval)

# Evaluate on test
y_prob_test = meta.predict_proba(X_test_meta)[:,1]
y_pred_test = (y_prob_test >= 0.5).astype(int)

print("Test Acc:", accuracy_score(y_test, y_pred_test))
print("Test F1 :", f1_score(y_test, y_pred_test))
try:
    print("Test AUC :", roc_auc_score(y_test, y_prob_test))
except Exception:
    pass

# Optional: find best threshold on eval (to maximize F1)
y_prob_eval = meta.predict_proba(X_eval_meta)[:,1]
best_t = 0.5; best_f1 = -1
for t in np.linspace(0.1, 0.9, 41):
    f = f1_score(y_eval, (y_prob_eval >= t).astype(int))
    if f > best_f1:
        best_f1 = f; best_t = t
print("Best threshold (tuned on eval):", best_t, "with F1:", best_f1)

# Save meta and feature arrays
joblib.dump(meta, "meta_lightgbm_tamil_from_eval_safe.joblib")
np.save("X_eval_meta.npy", X_eval_meta); np.save("y_eval.npy", y_eval)
np.save("X_test_meta.npy", X_test_meta); np.save("y_test.npy", y_test)
print("Saved meta and meta features. Done.")
# Out:
# DEVICE: cuda | TEXT_BATCH_SIZE: 16 | AUDIO_BATCH_SIZE: 2
# Eval size: 88 | Test size: 89
# Producing TEXT eval probs per model (one-at-a-time)...
#   -> ramesh070/mbert-hatespeechdetection-malayalam
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
#   -> ramesh070/xlm-r-hatespeechdetection-malayalam
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
#   -> ramesh070/indicbert-hatespeechdetection-malayalam
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Producing AUDIO eval probs per model (streaming, one-at-a-time)...
#   -> ramesh070/mms-malayalam-binary
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
#   -> ramesh070/wavlm-malayalam-binary
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:6044: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
#   -> ramesh070/wav2vec2-malayalam-binary
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Producing TEXT test probs per model...
#   -> ramesh070/mbert-hatespeechdetection-malayalam
#   -> ramesh070/xlm-r-hatespeechdetection-malayalam
#   -> ramesh070/indicbert-hatespeechdetection-malayalam
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Producing AUDIO test probs per model (streaming)...
#   -> ramesh070/mms-malayalam-binary
#   -> ramesh070/wavlm-malayalam-binary
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:6044: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
#   -> ramesh070/wav2vec2-malayalam-binary
# Training LightGBM meta on eval (OOF) features...
# Test Acc: 0.9662921348314607
# Test F1 : 0.9690721649484536
# Test AUC : 0.9989837398373983
# Best threshold (tuned on eval): 0.1 with F1: 1.0
# Saved meta and meta features. Done.

# %%
# === PLOTS: Confusion matrix, ROC, PR, Calibration, Feature importance, Histograms ===
import numpy as np
import matplotlib.pyplot as plt
import joblib
import os
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score,
    classification_report
)
from sklearn.calibration import calibration_curve

# Try to use variables in memory, otherwise load saved files
if 'meta' not in globals() and os.path.exists("meta_lightgbm_tamil_from_eval_safe.joblib"):
    meta = joblib.load("meta_lightgbm_tamil_from_eval_safe.joblib")
if 'X_test_meta' not in globals() and os.path.exists("X_test_meta.npy"):
    X_test_meta = np.load("X_test_meta.npy")
if 'y_test' not in globals() and os.path.exists("y_test.npy"):
    y_test = np.load("y_test.npy")
if 'X_eval_meta' not in globals() and os.path.exists("X_eval_meta.npy"):
    X_eval_meta = np.load("X_eval_meta.npy")
if 'y_eval' not in globals() and os.path.exists("y_eval.npy"):
    y_eval = np.load("y_eval.npy")

# Ensure we have predictions/probs
if 'y_prob_test' not in globals():
    y_prob_test = meta.predict_proba(X_test_meta)[:, 1]
if 'y_prob_eval' not in globals():
    y_prob_eval = meta.predict_proba(X_eval_meta)[:, 1]
y_pred_test = (y_prob_test >= 0.5).astype(int)

# --- 1) Confusion matrix + classification report -------------------------
cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['NotHate(0)', 'Hate(1)'])

plt.figure(figsize=(5,5))
disp.plot(cmap=plt.cm.Blues, values_format='d', ax=plt.gca())
plt.title("Confusion Matrix (Test)")
plt.grid(False)
plt.show()

print("Classification report (Test):")
print(classification_report(y_test, y_pred_test, digits=4))

# --- 2) ROC Curve --------------------------------------------------------
fpr, tpr, _ = roc_curve(y_test, y_prob_test)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.4f})")
plt.plot([0,1], [0,1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test)")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# --- 3) Precision-Recall Curve ------------------------------------------
precision, recall, _ = precision_recall_curve(y_test, y_prob_test)
ap = average_precision_score(y_test, y_prob_test)

plt.figure(figsize=(6,5))
plt.plot(recall, precision, label=f"PR (AP = {ap:.4f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve (Test)")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# --- 5) Feature importance (LightGBM) -----------------------------------
# meta.feature_importances_ is available for LGBMClassifier
try:
    fi = meta.feature_importances_
    feature_names = ['text_not', 'text_hate', 'audio_not', 'audio_hate']
    order = np.argsort(fi)[::-1]
    plt.figure(figsize=(6,3))
    plt.bar([feature_names[i] for i in order], fi[order])
    plt.title("LightGBM Feature Importances")
    plt.ylabel("Importance (gain/score)")
    plt.show()
except Exception as e:
    print("Could not plot feature importances:", e)

# --- 6) Histograms of meta features (sanity) ------------------------------
plt.figure(figsize=(10,6))
names = ['text_not','text_hate','audio_not','audio_hate']
for i in range(X_test_meta.shape[1]):
    plt.subplot(2,2,i+1)
    plt.hist(X_test_meta[:,i], bins=10, alpha=0.8)
    plt.title(names[i])
    plt.xlabel('prob')
    plt.ylabel('count')
plt.tight_layout()
plt.show()

# --- 7) Optional: Save figures to disk -----------------------------------
out_dir = "meta_plots"
os.makedirs(out_dir, exist_ok=True)
plt.savefig(os.path.join(out_dir, "last_plot.png"))  # saves last figure (hist). You can save others similarly.
print("Saved last plot to", os.path.join(out_dir, "last_plot.png"))
# Out:
# Classification report (Test):
#               precision    recall  f1-score   support
#
#            0     0.9750    0.9512    0.9630        41
#            1     0.9592    0.9792    0.9691        48
#
#     accuracy                         0.9663        89
#    macro avg     0.9671    0.9652    0.9660        89
# weighted avg     0.9665    0.9663    0.9663        89
# Saved last plot to meta_plots/last_plot.png
